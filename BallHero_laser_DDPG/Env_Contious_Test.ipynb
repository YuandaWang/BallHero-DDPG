# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from MazeEnv_Continuous import MazeSimulator
from itertools import count


settings = {
    'objects': [
        'friend',
        'enemy',
    ],
    'colors': {
        'hero':   'yellow',
        'friend': 'green',
        'enemy':  'red',
    },
    'object_reward': {
        'obstacle': -100,
        'wall': -100,
    },
    'hero_bounces_off_walls': False,
    'enemy_move':True,
    'world_size': (900,500),
    'hero_initial_position': [450, 250],
    'hero_initial_speed':    [0,   0],
    'end_position':          [750, 450],
    "maximum_speed":         [50, 50],
    "enemy_max_speed":       [50, 50],
    'max_angular_speed':1,
    'max_line_speed':50,
    'max_line_acc':200,

    "object_radius": 15.0,
    "hero_radius": 10,
    "num_objects": {
        "friend" : 0,
        "enemy" :  30,
    },
    "num_observation_lines" : 200,
    "observation_line_length": 200,
    "laser_buffer_length":1,
    "obstacle_tolerance":0.2,
    "delta_v": 50,
    "sim_dt":0.1,
}

# %%
sim = MazeSimulator(settings)
for i in range(10000):
    angular_speed = 0.1
    line_speed = 0.1
    s, r, d = sim.step(angular_speed, line_speed)
    sim.draw()
# Out:
# <svg.Scene instance at 0x7efd222a5908>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-62643e0ae5d7> in <module>()
#       3     angular_speed = 0.1
#       4     line_speed = 0.1
# ----> 5     s, r, d = sim.step(angular_speed, line_speed)
#       6     sim.draw()
#
# /home/yuanda/Learning/BallHero_DDPG/BallHero_laser_DDPG/MazeEnv_Continuous.pyc in step(self, a1, a2)
#     222
#     223         # 3. make observation
# --> 224         observation = self.observe()
#     225
#     226         # 4. collect reward
#
# /home/yuanda/Learning/BallHero_DDPG/BallHero_laser_DDPG/MazeEnv_Continuous.pyc in observe(self)
#     347                     proximity_wall = observable_distance
#     348                 else:
# --> 349                     proximity_wall = best_candidate.distance(self.hero.position)
#     350
#     351             # Deal with obstacles
#
# /home/yuanda/Learning/BallHero_DDPG/BallHero_laser_DDPG/euclid.pyc in distance(self, other)
#    1587
#    1588     def distance(self, other):
# -> 1589         c = self.connect(other)
#    1590         if c:
#    1591             return c.length
#
# KeyboardInterrupt:
