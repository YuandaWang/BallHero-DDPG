# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from MazeEnv_Continuous_Pic import MazeSimulator
from itertools import count


settings = {
    'objects': [
        'friend',
        'enemy',
    ],
    'colors': {
        'hero':   'yellow',
        'friend': 'green',
        'enemy':  'red',
    },
    'object_reward': {
        'obstacle': -100,
        'wall': -100,
    },
    'hero_bounces_off_walls': False,
    'enemy_move':True,
    'world_size': (500,500),
    'hero_initial_position': [450, 250],
    'hero_initial_speed':    [0,   0],
    'end_position':          [750, 450],
    "maximum_speed":         [50, 50],
    "enemy_max_speed":       [50, 50],
    'max_angular_speed':1,
    'max_line_speed':50,
    'max_line_acc':200,

    "object_radius": 15.0,
    "hero_radius": 10,
    "num_objects": {
        "friend" : 0,
        "enemy" :  30,
    },
    "num_observation_lines" : 200,
    "observation_line_length": 200,
    "laser_buffer_length":1,
    "obstacle_tolerance":0.2,
    "delta_v": 50,
    "sim_dt":0.1,
}

# %%
sim = MazeSimulator(settings)
for i in range(10000):
    angular_speed = 0.1
    line_speed = 0.1
    s, r, d = sim.step(angular_speed, line_speed)
    sim.draw()
# Out:
# <svg.Scene instance at 0x7f651809aef0>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-62643e0ae5d7> in <module>()
#       3     angular_speed = 0.1
#       4     line_speed = 0.1
# ----> 5     s, r, d = sim.step(angular_speed, line_speed)
#       6     sim.draw()
#
# /home/yuanda/Learning/BallHero_DDPG/BallHero_pic_DDPG/MazeEnv_Continuous_Pic.py in step(self, a1, a2)
#     222
#     223         # 3. make observation
# --> 224         observation = self.observe()
#     225
#     226         # 4. collect reward
#
# /home/yuanda/Learning/BallHero_DDPG/BallHero_pic_DDPG/MazeEnv_Continuous_Pic.py in observe(self)
#     355             if relevant_objects is not None:
#     356                 for obj in relevant_objects:
# --> 357                     if observation_line.distance(obj.position) < self.settings["object_radius"]:
#     358                         observed_object = obj
#     359                         break
#
# /home/yuanda/Learning/BallHero_DDPG/BallHero_pic_DDPG/euclid.py in distance(self, other)
#    1589         c = self.connect(other)
#    1590         if c:
# -> 1591             return c.length
#    1592         return 0.0
#    1593
#
# /home/yuanda/Learning/BallHero_DDPG/BallHero_pic_DDPG/euclid.py in <lambda>(self)
#    1835         return self
#    1836
# -> 1837     length = property(lambda self: abs(self.v))
#    1838
#    1839 class Circle(Geometry):
#
# /home/yuanda/Learning/BallHero_DDPG/BallHero_pic_DDPG/euclid.py in __abs__(self)
#     258     def __abs__(self):
#     259         return math.sqrt(self.x ** 2 + \
# --> 260                          self.y ** 2)
#     261
#     262     magnitude = __abs__
#
# KeyboardInterrupt:
